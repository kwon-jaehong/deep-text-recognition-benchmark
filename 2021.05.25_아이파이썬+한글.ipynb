# %%
import os
import sys
import time
import random
import string

import torch
import torch.backends.cudnn as cudnn
import torch.nn.init as init
import torch.optim as optim
import torch.utils.data
import numpy as np

from utils import CTCLabelConverter, CTCLabelConverterForBaiduWarpctc, AttnLabelConverter, Averager
from c_dataset import custom_Batch_Balanced_Dataset,custom_dataset,AlignCollate
from model import Model
from test import validation
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')



import torch.onnx
from torch.utils.tensorboard import SummaryWriter
from torchviz import make_dot

import easydict
global opt
opt = easydict.EasyDict({
    "exp_name": "test_01",
    "train_data": "/data/data/STARN/data_lmdb_release/training",
    "valid_data":"/data/data/STARN/data_lmdb_release/validation",
    "manualSeed": 1111,
    "workers": 6,
    "batch_size":8,
    "num_iter":300000,
    "valInterval":1,
    "saved_model":'',
    "FT":False,
    "adam":False,
    "lr":1,
    "beta1":0.9,
    "rho":0.95,
    "eps":1e-8,
    "grad_clip":5,
    "baiduCTC":False,
    "select_data":'ST',
    "batch_ratio":'1',
    "total_data_usage_ratio":'1.0',
    "batch_max_length":25,
    "imgW":100,
    "imgH":32,
    "rgb":False,
    "character":"0123456789abcdefghijklmnopqrstuvwxyz",
    "sensitive":False,
    "PAD":False,
    "data_filtering_off":False,
    "Transformation":"TPS",
    "FeatureExtraction":"ResNet",
    "SequenceModeling":"BiLSTM",
    "Prediction":'Attn',
    "num_fiducial":20,
    "input_channel":1,
    "output_channel":512,
    "hidden_size":256    
})

## batch_max_length 한 이미지에서의 최대 글자수 -> 디폴트값이 25이며, 한이미지에서 글자수 25자를 넘겨서는 안됨

def train(opt):
        
        
    opt.select_data = opt.select_data.split('-')
    opt.batch_ratio = opt.batch_ratio.split('-')

    train_dataset = custom_Batch_Balanced_Dataset(opt)
    valid_dataset = custom_dataset("/data/work_dir/img/generate_text_ko/mrjaehong_text_generation/generate_img/label.csv")
#     log = open(f'./saved_models/{opt.exp_name}/log_dataset.txt', 'a')
    AlignCollate_valid = AlignCollate(imgH=opt.imgH, imgW=opt.imgW, keep_ratio_with_pad=opt.PAD)
#     valid_dataset, valid_dataset_log = hierarchical_dataset(root=opt.valid_data, opt=opt)
    valid_loader = torch.utils.data.DataLoader(
        valid_dataset, batch_size=opt.batch_size,
        shuffle=True,  # 'True' to check training progress with validation function.
        num_workers=int(opt.workers),
        collate_fn=AlignCollate_valid, pin_memory=True)
# #     log.write(valid_dataset_log)
#     print('-' * 80)
#     log.write('-' * 80 + '\n')
#     log.close()
    
    
    numclass_path = "/data/work_dir/img/generate_text_ko/mrjaehong_text_generation/generate_img/ch_range.txt"
    f = open(numclass_path, 'r')
    ch_temp = f.read()
    f.close()
    opt.character = ch_temp

    converter = AttnLabelConverter(opt.character)
    opt.num_class = len(converter.character)

    
    
    
    ## 인풋채널 3으로 하셈
    opt.input_channel = 1
    model = Model(opt)
    print('model input parameters', opt.imgH, opt.imgW, opt.num_fiducial, opt.input_channel, opt.output_channel,
          opt.hidden_size, opt.num_class, opt.batch_max_length, opt.Transformation, opt.FeatureExtraction,
          opt.SequenceModeling, opt.Prediction)
    
    

    ## 웨이트값 초기화
    # weight initialization
    for name, param in model.named_parameters():
        if 'localization_fc2' in name:
            print(f'Skip {name} as it is already initialized')
            continue
        try:
            if 'bias' in name:
                init.constant_(param, 0.0)
            elif 'weight' in name:
                init.kaiming_normal_(param)
        except Exception as e:  # for batchnorm.
            if 'weight' in name:
                param.data.fill_(1)
            continue

            
            
    # data parallel for multi-GPU
    model = torch.nn.DataParallel(model).to(device)
    model.train()
    
    #
    if opt.saved_model != '':
        print(f'loading pretrained model from {opt.saved_model}')
        if opt.FT:
            model.load_state_dict(torch.load(opt.saved_model), strict=False)
        else:
            model.load_state_dict(torch.load(opt.saved_model))

            

    ## 로스값 구할때 go 토큰은 제외하고 계산
    criterion = torch.nn.CrossEntropyLoss(ignore_index=0).to(device)  # ignore [GO] token = ignore index 0
    # loss averager
    loss_avg = Averager()

    
    
    ## 이부분은 모르겟음
    ## 단순 학습가능한 파라메터를 출력 해주기 위함
#     filter that only require gradient decent
    filtered_parameters = []
    params_num = []
    for p in filter(lambda p: p.requires_grad, model.parameters()):
        filtered_parameters.append(p)
        params_num.append(np.prod(p.size()))
#     print('Trainable params num : ', sum(params_num))
    # [print(name, p.numel()) for name, p in filter(lambda p: p[1].requires_grad, model.named_parameters())]

    
    ## 옵티마이져 셋팅
    # setup optimizer
    if opt.adam:
        optimizer = optim.Adam(filtered_parameters, lr=opt.lr, betas=(opt.beta1, 0.999))
    else:
        optimizer = optim.Adadelta(filtered_parameters, lr=opt.lr, rho=opt.rho, eps=opt.eps)
#     print("Optimizer:")
#     print(optimizer)

    
    
#     ## 옵션 찍는거 삭제해도 됨
#     """ final options """
#     # print(opt)
#     with open(f'./saved_models/{opt.exp_name}/opt.txt', 'a') as opt_file:
#         opt_log = '------------ Options -------------\n'
#         args = vars(opt)
#         for k, v in args.items():
#             opt_log += f'{str(k)}: {str(v)}\n'
#         opt_log += '---------------------------------------\n'
#         print(opt_log)
#         opt_file.write(opt_log)

#     """ start training """
    start_iter = 0
#     if opt.saved_model != '':
#         try:
#             start_iter = int(opt.saved_model.split('_')[-1].split('.')[0])
#             print(f'continue to train, start_iter: {start_iter}')
#         except:
#             pass

        
        
    start_time = time.time()
    best_accuracy = -1
    best_norm_ED = -1
    iteration = start_iter

    while(True):
        # train part
        image_tensors, labels = train_dataset.get_batch()
        image = image_tensors.to(device)
        text, length = converter.encode(labels, batch_max_length=opt.batch_max_length)
        batch_size = image.size(0)

        if 'CTC' in opt.Prediction:
            preds = model(image, text)
            preds_size = torch.IntTensor([preds.size(1)] * batch_size)
            if opt.baiduCTC:
                preds = preds.permute(1, 0, 2)  # to use CTCLoss format
                cost = criterion(preds, text, preds_size, length) / batch_size
            else:
                preds = preds.log_softmax(2).permute(1, 0, 2)
                cost = criterion(preds, text, preds_size, length)

        else:
            preds = model(image, text[:, :-1])  # align with Attention.forward
            target = text[:, 1:]  # without [GO] Symbol
            cost = criterion(preds.view(-1, preds.shape[-1]), target.contiguous().view(-1))

        model.zero_grad()
        cost.backward()
        
        ## 그라디언트 https://sanghyu.tistory.com/87
        torch.nn.utils.clip_grad_norm_(model.parameters(), opt.grad_clip)  # gradient clipping with 5 (Default)
        optimizer.step()

        loss_avg.add(cost)

        # validation part
        if (iteration + 1) % opt.valInterval == 0 or iteration == 0: # To see training progress, we also conduct validation when 'iteration == 0' 
            elapsed_time = time.time() - start_time
            # for log
            with open(f'./saved_models/{opt.exp_name}/log_train.txt', 'a') as log:
                model.eval()
                with torch.no_grad():
                    valid_loss, current_accuracy, current_norm_ED, preds, confidence_score, labels, infer_time, length_of_data = validation(
                        model, criterion, valid_loader, converter, opt)
                model.train()

                # training loss and validation loss
                loss_log = f'[{iteration+1}/{opt.num_iter}] Train loss: {loss_avg.val():0.5f}, Valid loss: {valid_loss:0.5f}, Elapsed_time: {elapsed_time:0.5f}'
                loss_avg.reset()

                current_model_log = f'{"Current_accuracy":17s}: {current_accuracy:0.3f}, {"Current_norm_ED":17s}: {current_norm_ED:0.2f}'

                # keep best accuracy model (on valid dataset)
                if current_accuracy > best_accuracy:
                    best_accuracy = current_accuracy
                    torch.save(model.state_dict(), f'./saved_models/{opt.exp_name}/best_accuracy.pth')
                if current_norm_ED > best_norm_ED:
                    best_norm_ED = current_norm_ED
                    torch.save(model.state_dict(), f'./saved_models/{opt.exp_name}/best_norm_ED.pth')
                best_model_log = f'{"Best_accuracy":17s}: {best_accuracy:0.3f}, {"Best_norm_ED":17s}: {best_norm_ED:0.2f}'

                loss_model_log = f'{loss_log}\n{current_model_log}\n{best_model_log}'
                print(loss_model_log)
                log.write(loss_model_log + '\n')

                # show some predicted results
                dashed_line = '-' * 80
                head = f'{"Ground Truth":25s} | {"Prediction":25s} | Confidence Score & T/F'
                predicted_result_log = f'{dashed_line}\n{head}\n{dashed_line}\n'
                for gt, pred, confidence in zip(labels[:5], preds[:5], confidence_score[:5]):
                    if 'Attn' in opt.Prediction:
                        gt = gt[:gt.find('[s]')]
                        pred = pred[:pred.find('[s]')]

                    predicted_result_log += f'{gt:25s} | {pred:25s} | {confidence:0.4f}\t{str(pred == gt)}\n'
                predicted_result_log += f'{dashed_line}'
                print(predicted_result_log)
                log.write(predicted_result_log + '\n')

        # save model per 1e+5 iter.
        if (iteration + 1) % 1e+5 == 0:
            torch.save(
                model.state_dict(), f'./saved_models/{opt.exp_name}/iter_{iteration+1}.pth')

        if (iteration + 1) == opt.num_iter:
            print('end the training')
            sys.exit()
        iteration += 1


if __name__ == '__main__':

    if not opt.exp_name:
        opt.exp_name = f'{opt.Transformation}-{opt.FeatureExtraction}-{opt.SequenceModeling}-{opt.Prediction}'
        opt.exp_name += f'-Seed{opt.manualSeed}'
        # print(opt.exp_name)

    os.makedirs(f'./saved_models/{opt.exp_name}', exist_ok=True)

    """ vocab / character number configuration """
    if opt.sensitive:
        # opt.character += 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
        opt.character = string.printable[:-6]  # same with ASTER setting (use 94 char).

    """ Seed and GPU setting """
    # print("Random Seed: ", opt.manualSeed)
    random.seed(opt.manualSeed)
    np.random.seed(opt.manualSeed)
    torch.manual_seed(opt.manualSeed)
    torch.cuda.manual_seed(opt.manualSeed)

    cudnn.benchmark = True
    cudnn.deterministic = True
    opt.num_gpu = torch.cuda.device_count()
    # print('device count', opt.num_gpu)
    if opt.num_gpu > 1:
        print('------ Use multi-GPU setting ------')
        print('if you stuck too long time with multi-GPU setting, try to set --workers 0')
        # check multi-GPU issue https://github.com/clovaai/deep-text-recognition-benchmark/issues/1
        opt.workers = opt.workers * opt.num_gpu
        opt.batch_size = opt.batch_size * opt.num_gpu

        """ previous version
        print('To equlize batch stats to 1-GPU setting, the batch_size is multiplied with num_gpu and multiplied batch_size is ', opt.batch_size)
        opt.batch_size = opt.batch_size * opt.num_gpu
        print('To equalize the number of epochs to 1-GPU setting, num_iter is divided with num_gpu by default.')
        If you dont care about it, just commnet out these line.)
        opt.num_iter = int(opt.num_iter / opt.num_gpu)
        """

    train(opt)
# Out:
# ------ Use multi-GPU setting ------
# if you stuck too long time with multi-GPU setting, try to set --workers 0
# model input parameters 32 100 20 1 512 256 729 25 TPS ResNet BiLSTM Attn
# Skip Transformation.LocalizationNetwork.localization_fc2.weight as it is already initialized
# Skip Transformation.LocalizationNetwork.localization_fc2.bias as it is already initialized
# [1/300000] Train loss: 6.61593, Valid loss: 6.55326, Elapsed_time: 11.44880
# Current_accuracy : 0.000, Current_norm_ED  : 0.00
# Best_accuracy    : 0.000, Best_norm_ED     : 0.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 조아욥                       | 깁깁확확확확확확확확확확칫확확확칫확확칫확확칫확확 | 0.0000	False
# 좋아요 슨                     | 확확확확확확확확확확확확확확확확확확확확확확확확확 | 0.0000	False
# 음 그냥                      | 츄츄츄확츄확츄확츄확츄확츄확츄확확츄확확츄확확츄확 | 0.0000	False
# 로                         | 훗깁확확확확확프확확확확확확확확확확확확난프확확확 | 0.0000	False
# 파아다래챁                     | 츄깁츄확확츄확츄확확확확확확확확확확확확확확확확확 | 0.0000	False
# --------------------------------------------------------------------------------
# [2/300000] Train loss: 6.46953, Valid loss: 6.49544, Elapsed_time: 27.10114
# Current_accuracy : 0.000, Current_norm_ED  : 0.00
# Best_accuracy    : 0.000, Best_norm_ED     : 0.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 내뉴느니너                     | 쭈쭈쭈쭈쭈쭈쭈쭈쭈쭈쭈쭈쭈쭈쭈쭈쭈쭈쭈쭈쭈쭈쭈쭈쭈 | 0.0000	False
# 펀안합니자                     | 쭈라라라라라라라라라라라라라라라라라라라라라라라라 | 0.0000	False
# 재밋네요                      | 쭈라라라라라욧라욧라욧라라라욧라라라라욧라라라라라 | 0.0000	False
# 섹시                        | 쭈쭈                        | 0.0000	False
# 디슨독디                      | 쭈쭈라쭈라프라프프프프프프프프프프프프프프프프프프 | 0.0000	False
# --------------------------------------------------------------------------------
# [3/300000] Train loss: 6.33845, Valid loss: 6.39888, Elapsed_time: 41.57400
# Current_accuracy : 0.000, Current_norm_ED  : 0.00
# Best_accuracy    : 0.000, Best_norm_ED     : 0.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 좋습니다                      |                           | 0.0000	False
# 조아요                       |                           | 0.0000	False
# 좋아요                       |                           | 0.0000	False
# 이쁩니다능                     |                           | 0.0000	False
# 이쁩니다                      |                           | 0.0000	False
# --------------------------------------------------------------------------------
# [4/300000] Train loss: 6.15715, Valid loss: 6.18918, Elapsed_time: 56.98042
# Current_accuracy : 0.000, Current_norm_ED  : 0.00
# Best_accuracy    : 0.000, Best_norm_ED     : 0.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 11 겟또                     |                           | 0.0000	False
# 천찾히나                      |                           | 0.0000	False
# 좋아오                       |                           | 0.0000	False
# 녹녹녹                       |                           | 0.0000	False
# 그저그렇네                     |                           | 0.0000	False
# --------------------------------------------------------------------------------
# [5/300000] Train loss: 5.88378, Valid loss: 5.98169, Elapsed_time: 72.70539
# Current_accuracy : 0.000, Current_norm_ED  : 0.00
# Best_accuracy    : 0.000, Best_norm_ED     : 0.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 구두같음굿                     |                           | 0.0000	False
# 빠르네요                      |                           | 0.0000	False
# 앎                         |                           | 0.0000	False
# 짧아서놀람                     |                           | 0.0000	False
# 재구매                       |                           | 0.0000	False
# --------------------------------------------------------------------------------
# [6/300000] Train loss: 5.69087, Valid loss: 5.64986, Elapsed_time: 88.21780
# Current_accuracy : 0.000, Current_norm_ED  : 0.00
# Best_accuracy    : 0.000, Best_norm_ED     : 0.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 방음력                       |                           | 0.0000	False
# 잘쓸게요                      |                           | 0.0000	False
# 별로에요                      |                           | 0.0000	False
# 잘왔어용                      |                           | 0.0000	False
# 가냥그래여                     |                           | 0.0000	False
# --------------------------------------------------------------------------------
# [7/300000] Train loss: 5.46917, Valid loss: 5.41070, Elapsed_time: 104.02200
# Current_accuracy : 0.000, Current_norm_ED  : 0.00
# Best_accuracy    : 0.000, Best_norm_ED     : 0.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 만독한비다                     |                           | 0.0000	False
# 말려올라감                     |                           | 0.0000	False
# 올소첲                       |                           | 0.0000	False
# 난 별로                      |                           | 0.0000	False
# 이뻐용굿굿                     |                           | 0.0000	False
# --------------------------------------------------------------------------------
# [8/300000] Train loss: 5.32128, Valid loss: 5.37774, Elapsed_time: 119.44392
# Current_accuracy : 0.000, Current_norm_ED  : 0.00
# Best_accuracy    : 0.000, Best_norm_ED     : 0.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 영 불만족                     |                           | 0.0000	False
# 렸토터코큐                     |                           | 0.0000	False
# 터져왔네요                     |                           | 0.0000	False
# 조아욥                       |                           | 0.0000	False
# 만조쿠테스                     |                           | 0.0000	False
# --------------------------------------------------------------------------------
# [9/300000] Train loss: 5.24417, Valid loss: 5.23012, Elapsed_time: 134.97579
# Current_accuracy : 0.000, Current_norm_ED  : 0.00
# Best_accuracy    : 0.000, Best_norm_ED     : 0.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 그저그래요                     |                           | 0.0000	False
# 좋네요                       |                           | 0.0000	False
# 인생템                       |                           | 0.0000	False
# 터치율                       |                           | 0.0000	False
# 안찢어져요                     |                           | 0.0000	False
# --------------------------------------------------------------------------------
# [10/300000] Train loss: 5.11165, Valid loss: 5.28747, Elapsed_time: 150.87236
# Current_accuracy : 0.000, Current_norm_ED  : 0.07
# Best_accuracy    : 0.000, Best_norm_ED     : 0.07
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 잘안맞아요                     | 요요요요요                     | 0.0000	False
# 조끝네                       | 요요요요요                     | 0.0000	False
# 옵션짜증남                     | 요요요요요요                    | 0.0000	False
# 그 냥                       | 요요요요요                     | 0.0000	False
# 화려강산안                     | 요요요요요                     | 0.0000	False
# --------------------------------------------------------------------------------
# [11/300000] Train loss: 5.25654, Valid loss: 5.14250, Elapsed_time: 165.38321
# Current_accuracy : 0.000, Current_norm_ED  : 0.00
# Best_accuracy    : 0.000, Best_norm_ED     : 0.07
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 예쁘네용                      |                           | 0.0000	False
# 11 겟또                     |                           | 0.0000	False
# 짜증남                       |                           | 0.0000	False
# 이거 뭥미                     |                           | 0.0000	False
# 기스났어요                     |                           | 0.0000	False
# --------------------------------------------------------------------------------
# [12/300000] Train loss: 5.33923, Valid loss: 5.16831, Elapsed_time: 181.06303
# Current_accuracy : 0.000, Current_norm_ED  : 0.03
# Best_accuracy    : 0.000, Best_norm_ED     : 0.07
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 별로별별로                     | 요                         | 0.0117	False
# 별로에요오                     | 요요                        | 0.0004	False
# 딱딱해요                      |                           | 0.0000	False
# 괜츈해여                      | 요요                        | 0.0003	False
# 맛나더이다                     | 요요                        | 0.0003	False
# --------------------------------------------------------------------------------
# [13/300000] Train loss: 5.20437, Valid loss: 5.05731, Elapsed_time: 196.09604
# Current_accuracy : 0.000, Current_norm_ED  : 0.00
# Best_accuracy    : 0.000, Best_norm_ED     : 0.07
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 만족합니다                     |                           | 0.0000	False
# 너무큽니다                     |                           | 0.0000	False
# 재구매                       |                           | 0.0000	False
# 음                         |                           | 0.0000	False
# 음                         |                           | 0.0000	False
# --------------------------------------------------------------------------------
# [14/300000] Train loss: 5.13881, Valid loss: 5.03865, Elapsed_time: 211.68454
# Current_accuracy : 0.000, Current_norm_ED  : 0.07
# Best_accuracy    : 0.000, Best_norm_ED     : 0.07
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 넘 짜네여                     | 요                         | 0.0131	False
# 택배회사만                     | 요                         | 0.0137	False
# 싼마이                       | 요                         | 0.0138	False
# 좋아욪아                      | 요                         | 0.0133	False
# 좋네요                       | 요                         | 0.0137	False
# --------------------------------------------------------------------------------
# [15/300000] Train loss: 5.09910, Valid loss: 4.95601, Elapsed_time: 225.86388
# Current_accuracy : 0.000, Current_norm_ED  : 0.00
# Best_accuracy    : 0.000, Best_norm_ED     : 0.07
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 아주좋아                      |                           | 0.0000	False
# 좋아요                       |                           | 0.0000	False
# 시원시원                      |                           | 0.0000	False
#  늦게옴                      |                           | 0.0000	False
# 줄줄새서옴                     |                           | 0.0000	False
# --------------------------------------------------------------------------------
# [16/300000] Train loss: 4.92368, Valid loss: 4.91996, Elapsed_time: 241.33246
# Current_accuracy : 0.067, Current_norm_ED  : 0.08
# Best_accuracy    : 0.067, Best_norm_ED     : 0.08
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 그냥그래요                     | 요                         | 0.0156	False
# 좋습니다                      | 요                         | 0.0158	False
# 재구매                       | 요                         | 0.0155	False
# 맛이없어요                     |                           | 0.0000	False
# 구매실패                      | 요                         | 0.0156	False
# --------------------------------------------------------------------------------
# [17/300000] Train loss: 4.95019, Valid loss: 4.93487, Elapsed_time: 256.50863
# Current_accuracy : 0.000, Current_norm_ED  : 0.00
# Best_accuracy    : 0.067, Best_norm_ED     : 0.08
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 재구매                       |                           | 0.0000	False
# 긋굿수굿굿                     |                           | 0.0000	False
#  긋                        |                           | 0.0000	False
# 빠른배송굿                     |                           | 0.0000	False
# 아쉬워요                      |                           | 0.0000	False
# --------------------------------------------------------------------------------
# [18/300000] Train loss: 5.02049, Valid loss: 4.92614, Elapsed_time: 272.09510
# Current_accuracy : 0.000, Current_norm_ED  : 0.08
# Best_accuracy    : 0.067, Best_norm_ED     : 0.08
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 아터오                       | 요요요                       | 0.0001	False
# 귻                         | 요요                        | 0.0009	False
# 재미있어요                     | 요요                        | 0.0007	False
# 오졋다리용                     | 요요                        | 0.0009	False
# 좋습니다요                     | 요요요                       | 0.0001	False
# --------------------------------------------------------------------------------
# [19/300000] Train loss: 4.92109, Valid loss: 4.86894, Elapsed_time: 286.56147
# Current_accuracy : 0.000, Current_norm_ED  : 0.07
# Best_accuracy    : 0.067, Best_norm_ED     : 0.08
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 로                         | 요                         | 0.0224	False
# 조아요                       | 요                         | 0.0225	False
# 배송 느림                     | 요                         | 0.0222	False
# 말려올라감                     |                           | 0.0000	False
#  잘써요                      | 요                         | 0.0216	False
# --------------------------------------------------------------------------------
# [20/300000] Train loss: 4.96264, Valid loss: 4.89800, Elapsed_time: 300.78975
# Current_accuracy : 0.000, Current_norm_ED  : 0.08
# Best_accuracy    : 0.067, Best_norm_ED     : 0.08
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 떡져있네요                     | 요요요요요                     | 0.0000	False
# 잘못시킴                      | 요요요요요                     | 0.0000	False
#  즌                        | 요요요요                      | 0.0000	False
# 가격굿                       | 요요요요                      | 0.0000	False
# 굣                         | 요요요요                      | 0.0000	False
# --------------------------------------------------------------------------------
# [21/300000] Train loss: 4.95567, Valid loss: 4.85812, Elapsed_time: 314.63563
# Current_accuracy : 0.000, Current_norm_ED  : 0.00
# Best_accuracy    : 0.067, Best_norm_ED     : 0.08
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 러추투크쿠                     |                           | 0.0000	False
# 사이즈커요                     |                           | 0.0000	False
# 만족만족중                     |                           | 0.0000	False
# 새서왔어요                     |                           | 0.0000	False
# 너누자캌                      |                           | 0.0000	False
# --------------------------------------------------------------------------------
# [22/300000] Train loss: 4.96273, Valid loss: 4.88768, Elapsed_time: 330.16192
# Current_accuracy : 0.000, Current_norm_ED  : 0.08
# Best_accuracy    : 0.067, Best_norm_ED     : 0.08
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 별루에요                      | 요요요요                      | 0.0000	False
# 이하동문                      | 요요요요                      | 0.0000	False
# 잘안맞네요                     | 요요요                       | 0.0000	False
# 음 그냥                      | 요요요                       | 0.0001	False
# 꼭효과있길                     | 요요요요                      | 0.0000	False
# --------------------------------------------------------------------------------
# [23/300000] Train loss: 4.82281, Valid loss: 4.76087, Elapsed_time: 344.02496
# Current_accuracy : 0.000, Current_norm_ED  : 0.00
# Best_accuracy    : 0.067, Best_norm_ED     : 0.08
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 좋음                        |                           | 0.0000	False
# 너무커요                      |                           | 0.0000	False
# 오졋다리용                     |                           | 0.0000	False
# 늘 좋아요                     |                           | 0.0000	False
# 짱짱좋아연                     |                           | 0.0000	False
# --------------------------------------------------------------------------------
# [24/300000] Train loss: 4.76579, Valid loss: 4.74311, Elapsed_time: 359.52113
# Current_accuracy : 0.000, Current_norm_ED  : 0.03
# Best_accuracy    : 0.067, Best_norm_ED     : 0.08
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 좋아여염                      | 좋                         | 0.0225	False
# 앙만족띠                      | 좋                         | 0.0226	False
# 오큐                        | 좋                         | 0.0228	False
# 대박                        | 좋                         | 0.0236	False
# 러오                        | 좋                         | 0.0197	False
# --------------------------------------------------------------------------------
# [25/300000] Train loss: 4.63485, Valid loss: 4.74828, Elapsed_time: 373.00541
# Current_accuracy : 0.000, Current_norm_ED  : 0.07
# Best_accuracy    : 0.067, Best_norm_ED     : 0.08
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 좋았어요                      | 요                         | 0.0194	False
# 최악입니다                     | 요                         | 0.0198	False
# 넘예뻐요                      | 요                         | 0.0212	False
# 맛있어요                      | 요                         | 0.0202	False
# 시식전이라                     | 요                         | 0.0169	False
# --------------------------------------------------------------------------------
# [26/300000] Train loss: 4.56709, Valid loss: 4.71574, Elapsed_time: 386.73483
# Current_accuracy : 0.733, Current_norm_ED  : 0.12
# Best_accuracy    : 0.733, Best_norm_ED     : 0.12
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 빠름빠름                      | 요요요                       | 0.0001	False
# 이하동문                      | 좋요요                       | 0.0001	False
# 잘신을게요                     | 좋요요                       | 0.0001	False
# 짜요짜요짜                     | 좋요요                       | 0.0001	False
# 조아요                       | 좋아요                       | 0.0002	False
# --------------------------------------------------------------------------------
# [27/300000] Train loss: 4.68196, Valid loss: 4.71383, Elapsed_time: 401.26906
# Current_accuracy : 0.000, Current_norm_ED  : 0.03
# Best_accuracy    : 0.733, Best_norm_ED     : 0.12
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 즌긱                        | 좋                         | 0.0259	False
# 배송이                       | 좋                         | 0.0258	False
# 너무짭니다                     | 좋                         | 0.0279	False
# 잘쓸게요오                     | 좋                         | 0.0191	False
# 대만족                       | 좋                         | 0.0235	False
# --------------------------------------------------------------------------------
# [28/300000] Train loss: 4.71100, Valid loss: 4.78504, Elapsed_time: 414.65598
# Current_accuracy : 0.000, Current_norm_ED  : 0.09
# Best_accuracy    : 0.733, Best_norm_ED     : 0.12
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 너무약함                      | 좋좋요요요                     | 0.0000	False
# 마싯으요으                     | 좋 요요요                     | 0.0000	False
# 별로 걍즈                     | 좋좋요요요                     | 0.0000	False
# 핳터 터                      | 좋좋요요요                     | 0.0000	False
# 구                         | 좋 요요                      | 0.0000	False
# --------------------------------------------------------------------------------
# [29/300000] Train loss: 4.85777, Valid loss: 4.73526, Elapsed_time: 428.18723
# Current_accuracy : 0.000, Current_norm_ED  : 0.02
# Best_accuracy    : 0.733, Best_norm_ED     : 0.12
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 괜찮아요                      | 좋                         | 0.0213	False
# 좋아용                       | 좋                         | 0.0223	False
# 안비려요                      |                           | 0.0000	False
# 보통이예요                     |                           | 0.0000	False
# 그 냥                       |                           | 0.0000	False
# --------------------------------------------------------------------------------
# [30/300000] Train loss: 4.79291, Valid loss: 4.74113, Elapsed_time: 443.04755
# Current_accuracy : 0.000, Current_norm_ED  : 0.11
# Best_accuracy    : 0.733, Best_norm_ED     : 0.12
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 쇠맛나요                      |   요                       | 0.0001	False
# 예버요                       | 좋 요                       | 0.0001	False
# 비                         |   요                       | 0.0001	False
# 넘잡아요                      | 좋 요                       | 0.0001	False
# 좋아요구굿                     | 좋 요                       | 0.0001	False
# --------------------------------------------------------------------------------
# [31/300000] Train loss: 4.72231, Valid loss: 4.65638, Elapsed_time: 456.52286
# Current_accuracy : 0.000, Current_norm_ED  : 0.05
# Best_accuracy    : 0.733, Best_norm_ED     : 0.12
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 좋습니다                      | 좋                         | 0.0173	False
# 맍녹합니                      |                           | 0.0000	False
# 괜히삿어요                     | 좋                         | 0.0167	False
# 재구매                       |                           | 0.0000	False
# 너무낮아요                     | 좋                         | 0.0166	False
# --------------------------------------------------------------------------------
# [32/300000] Train loss: 4.84528, Valid loss: 4.64271, Elapsed_time: 471.00730
# Current_accuracy : 0.000, Current_norm_ED  : 0.06
# Best_accuracy    : 0.733, Best_norm_ED     : 0.12
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 쓸만합니다                     | 좋                         | 0.0208	False
# 걍 좋네요                     | 좋아                        | 0.0011	False
# 소리심해요                     | 좋                         | 0.0122	False
# 으귀야워요                     | 좋                         | 0.0155	False
# 별로예요                      | 좋아                        | 0.0010	False
# --------------------------------------------------------------------------------
# [33/300000] Train loss: 4.69387, Valid loss: 4.61201, Elapsed_time: 484.95872
# Current_accuracy : 0.000, Current_norm_ED  : 0.03
# Best_accuracy    : 0.733, Best_norm_ED     : 0.12
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 귀욤                        | 좋                         | 0.0205	False
# 안찢어져요                     | 좋                         | 0.0193	False
# 조아용                       | 좋                         | 0.0205	False
# 싸고 좋넹                     | 좋                         | 0.0165	False
# 오츄                        | 좋                         | 0.0196	False
# --------------------------------------------------------------------------------
# [34/300000] Train loss: 4.71572, Valid loss: 4.62912, Elapsed_time: 498.46159
# Current_accuracy : 0.000, Current_norm_ED  : 0.08
# Best_accuracy    : 0.733, Best_norm_ED     : 0.12
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 휴                         |                           | 0.0015	False
# 재구매                       | 좋                         | 0.0006	False
# 배송 느림                     |                           | 0.0014	False
# 별루에요                      | 좋                         | 0.0014	False
# 좋이요                       | 좋                         | 0.0008	False
# --------------------------------------------------------------------------------
# [35/300000] Train loss: 4.46688, Valid loss: 4.60744, Elapsed_time: 511.97798
# Current_accuracy : 0.000, Current_norm_ED  : 0.11
# Best_accuracy    : 0.733, Best_norm_ED     : 0.12
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 매우늦게옴                     | 요요                        | 0.0016	False
# 구두같음굿                     | 요요                        | 0.0020	False
# 구우우웃                      |                           | 0.0020	False
# 안맞아요                      | 좋요                        | 0.0017	False
# 좋아요                       |                           | 0.0021	False
# --------------------------------------------------------------------------------
# [36/300000] Train loss: 4.64944, Valid loss: 4.65578, Elapsed_time: 525.47515
# Current_accuracy : 0.000, Current_norm_ED  : 0.12
# Best_accuracy    : 0.733, Best_norm_ED     : 0.12
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 재구매                       | 좋아요요                      | 0.0000	False
# 맛없어요                      | 좋아요                       | 0.0001	False
# 서서서서                      | 좋아요요                      | 0.0000	False
# 돈아깝네요                     | 좋  요                      | 0.0000	False
# 뽀송뽀송행                     | 좋아요요                      | 0.0000	False
# --------------------------------------------------------------------------------
# [37/300000] Train loss: 4.44891, Valid loss: 4.64782, Elapsed_time: 538.83354
# Current_accuracy : 0.000, Current_norm_ED  : 0.03
# Best_accuracy    : 0.733, Best_norm_ED     : 0.12
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 퓨                         | 좋                         | 0.0300	False
# 저아요추천                     | 좋                         | 0.0268	False
# 별로에요                      | 좋                         | 0.0299	False
# 쵳쳬리리리                     | 좋                         | 0.0292	False
# 아주좋아요                     | 좋                         | 0.0267	False
# --------------------------------------------------------------------------------
# [38/300000] Train loss: 4.68001, Valid loss: 4.61235, Elapsed_time: 552.47478
# Current_accuracy : 0.000, Current_norm_ED  : 0.06
# Best_accuracy    : 0.733, Best_norm_ED     : 0.12
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 효                         | 좋                         | 0.0013	False
# 별그닺                       | 좋                         | 0.0013	False
# 딱딱해요                      | 좋좋                        | 0.0013	False
# 완전 깔끔                     | 좋좋                        | 0.0014	False
# 너재내내낸                     | 좋좋                        | 0.0011	False
# --------------------------------------------------------------------------------
# [39/300000] Train loss: 4.41088, Valid loss: 4.60920, Elapsed_time: 566.17033
# Current_accuracy : 0.000, Current_norm_ED  : 0.05
# Best_accuracy    : 0.733, Best_norm_ED     : 0.12
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 맛이없어요                     | 좋                         | 0.0226	False
# 맛이좋네요                     | 좋                         | 0.0225	False
# 좋아요 슨                     | 좋                         | 0.0196	False
# 그닥                        |                           | 0.0274	False
# 발아파요                      | 좋                         | 0.0248	False
# --------------------------------------------------------------------------------
# [40/300000] Train loss: 4.78125, Valid loss: 4.59447, Elapsed_time: 579.57179
# Current_accuracy : 0.000, Current_norm_ED  : 0.12
# Best_accuracy    : 0.733, Best_norm_ED     : 0.12
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 좋아요                       | 좋                         | 0.0002	False
# 한맛                        | 좋                         | 0.0002	False
# 조아영                       | 좋                         | 0.0002	False
# 마시쪙후훗                     | 좋                         | 0.0002	False
# 졸라별로임                     | 좋요요                       | 0.0001	False
# --------------------------------------------------------------------------------
# [41/300000] Train loss: 4.86358, Valid loss: 4.61575, Elapsed_time: 593.71256
# Current_accuracy : 0.000, Current_norm_ED  : 0.03
# Best_accuracy    : 0.733, Best_norm_ED     : 0.12
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 순면아닌데                     | 좋                         | 0.0185	False
# 아재우러대                     | 좋                         | 0.0210	False
#  별로네영                     | 좋                         | 0.0205	False
# 굿                         | 좋                         | 0.0175	False
# 괜찮아요                      | 좋                         | 0.0167	False
# --------------------------------------------------------------------------------
# [42/300000] Train loss: 4.46408, Valid loss: 4.55765, Elapsed_time: 607.46560
# Current_accuracy : 0.000, Current_norm_ED  : 0.08
# Best_accuracy    : 0.733, Best_norm_ED     : 0.12
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 개져아기                      | 좋                         | 0.0014	False
# 장받았어요                     | 좋                         | 0.0008	False
# 넘작네요                      | 좋                         | 0.0021	False
# 돈아까비잉                     | 좋                         | 0.0007	False
# 벌레많음                      | 좋                         | 0.0022	False
# --------------------------------------------------------------------------------
# [43/300000] Train loss: 4.72738, Valid loss: 4.52350, Elapsed_time: 621.10525
# Current_accuracy : 0.000, Current_norm_ED  : 0.10
# Best_accuracy    : 0.733, Best_norm_ED     : 0.12
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 글쎄요                       | 좋요                        | 0.0010	False
# 좋읍니다요                     | 좋요                        | 0.0008	False
# 참 편해요                     | 좋                         | 0.0016	False
# 부들부들함                     | 좋                         | 0.0252	False
# 조상와                       | 좋                         | 0.0020	False
# --------------------------------------------------------------------------------
# [44/300000] Train loss: 4.24595, Valid loss: 4.51580, Elapsed_time: 634.68834
# Current_accuracy : 0.000, Current_norm_ED  : 0.11
# Best_accuracy    : 0.733, Best_norm_ED     : 0.12
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 음글쎄요                      | 좋요요                       | 0.0003	False
# 재구매                       | 좋요요                       | 0.0002	False
# 어아뉸                       | 좋                         | 0.0031	False
# 맘족핮다                      | 좋                         | 0.0021	False
# 너무이머요                     | 좋요요                       | 0.0002	False
# --------------------------------------------------------------------------------
# [45/300000] Train loss: 4.64307, Valid loss: 4.51932, Elapsed_time: 648.29133
# Current_accuracy : 0.000, Current_norm_ED  : 0.08
# Best_accuracy    : 0.733, Best_norm_ED     : 0.12
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 맘에들어요                     | 좋아                        | 0.0012	False
# 븍징습디이                     | 좋                         | 0.0281	False
# 휴                         | 좋                         | 0.0297	False
# 허포추첯사                     | 좋                         | 0.0314	False
# 택배가느림                     | 좋                         | 0.0316	False
# --------------------------------------------------------------------------------
# [46/300000] Train loss: 4.60343, Valid loss: 4.52537, Elapsed_time: 662.82085
# Current_accuracy : 0.133, Current_norm_ED  : 0.10
# Best_accuracy    : 0.733, Best_norm_ED     : 0.12
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 조아조오                      | 좋                         | 0.0005	False
# 고장잘남요                     | 좋아요                       | 0.0001	False
# 좋아요튼튼                     | 좋                         | 0.0003	False
# 어아뉸                       | 좋                         | 0.0005	False
# 안좋음                       | 좋                         | 0.0004	False
# --------------------------------------------------------------------------------
# [47/300000] Train loss: 4.82702, Valid loss: 4.50435, Elapsed_time: 677.08228
# Current_accuracy : 0.000, Current_norm_ED  : 0.09
# Best_accuracy    : 0.733, Best_norm_ED     : 0.12
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 나름예뻐요                     | 좋요                        | 0.0006	False
#  싣그는                      |                           | 0.0038	False
# 너무 짜요                     | 좋                         | 0.0022	False
# 만족합니다                     | 좋요                        | 0.0008	False
# 늩흕솢긴                      |                           | 0.0027	False
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-1-beec91464580> in <module>
#     326         """
#     327
# --> 328     train(opt)
#
# <ipython-input-1-beec91464580> in train(opt)
#     202     while(True):
#     203         # train part
# --> 204         image_tensors, labels = train_dataset.get_batch()
#     205         image = image_tensors.to(device)
#     206         text, length = converter.encode(labels, batch_max_length=opt.batch_max_length)
#
# /data/work_dir/img/text_recognition/deep-text-recognition-benchmark/c_dataset.py in get_batch(self)
#      74
#      75         for i, data_loader_iter in enumerate(self.dataloader_iter_list):
# ---> 76             image, text = data_loader_iter.next()
#      77             balanced_batch_images.append(image)
#      78             balanced_batch_texts += text
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     515             if self._sampler_iter is None:
#     516                 self._reset()
# --> 517             data = self._next_data()
#     518             self._num_yielded += 1
#     519             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1170                 if not self._persistent_workers:
#    1171                     self._shutdown_workers()
# -> 1172                 raise StopIteration
#    1173
#    1174             # Now `self._rcvd_idx` is the batch index we want to fetch
#
# StopIteration:
